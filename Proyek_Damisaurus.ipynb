# %% [markdown]
# ## Prediksi Customer pengaju Pinjaman di Bank XYZ
# =====================================================================

# %%
# Author : Rusmina Siahaan (12S16011)
#          Chandro Pardede (12S16025)
#          Wiwiwn Gurning  (12S16060)

# %% [markdown]
# ###  IMPORT LIBRARY

# %%
import pandas as pd
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

data = pd.read_csv('E:/Materi Kuliah/Semester 7/DAMI/PROYEK/credit_train.csv')
data1 = pd.read_csv('E:/Materi Kuliah/Semester 7/DAMI/PROYEK/credit_test.csv')

# %%
data.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
# 3  77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a  e777faab-98ae-45af-9a86-7ce5b33b1011
# 4  d4062e70-befa-4995-8643-a0de73938182  81536ad9-5ccf-4eb8-befb-47a4d608658e
#
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term           NaN            NaN
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
# 3  Fully Paid             347666.0   Long Term         721.0       806949.0
# 4  Fully Paid             176220.0  Short Term           NaN            NaN
#
# ...

# %%
data1.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  f738779f-c726-40dc-92cf-689d73af533d  ded0b3c3-6bf4-4091-8726-47039f2c1b90
# 1  6dcc0947-164d-476c-a1de-3ae7283dde0a  1630e6e3-34e3-461a-8fda-09297d3140c8
# 2  f7744d01-894b-49c3-8777-fc6431a2cff1  2c60938b-ad2b-4702-804d-eeca43949c52
# 3  83721ffb-b99a-4a0f-aea5-ef472a138b41  12116614-2f3c-4d16-ad34-d92883718806
# 4  08f3789f-5714-4b10-929d-e1527ab5e5a3  39888105-fd5f-4023-860a-30a3e6f5ccb7
#
#    Current Loan Amount        Term  Credit Score  Annual Income  \
# 0             611314.0  Short Term         747.0      2074116.0
# 1             266662.0  Short Term         734.0      1919190.0
# 2             153494.0  Short Term         709.0       871112.0
# 3             176242.0  Short Term         727.0       780083.0
# 4             321992.0  Short Term         744.0      1761148.0
#
#   Years in current job Home Ownership             Purpose  Monthly Debt  \
# ...

# %%
data['Loan Status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off', nan], dtype=object)

# %%
data.describe()
# Out:
#        Current Loan Amount  Credit Score  Annual Income   Monthly Debt  \
# count         1.000000e+05  80846.000000   8.084600e+04  100000.000000
# mean          1.176045e+07   1076.456089   1.378277e+06   18472.412336
# std           3.178394e+07   1475.403791   1.081360e+06   12174.992609
# min           1.080200e+04    585.000000   7.662700e+04       0.000000
# 25%           1.796520e+05    705.000000   8.488440e+05   10214.162500
# 50%           3.122460e+05    724.000000   1.174162e+06   16220.300000
# 75%           5.249420e+05    741.000000   1.650663e+06   24012.057500
# max           1.000000e+08   7510.000000   1.655574e+08  435843.280000
#
#        Years of Credit History  Months since last delinquent  \
# count            100000.000000                  46859.000000
# mean                 18.199141                     34.901321
# std                   7.015324                     21.997829
# min                   3.600000                      0.000000
# ...

# %%
data.dtypes
# Out:
# Loan ID                          object
# Customer ID                      object
# Loan Status                      object
# Current Loan Amount             float64
# Term                             object
# Credit Score                    float64
# Annual Income                   float64
# Years in current job             object
# Home Ownership                   object
# Purpose                          object
# Monthly Debt                    float64
# Years of Credit History         float64
# Months since last delinquent    float64
# Number of Open Accounts         float64
# Number of Credit Problems       float64
# Current Credit Balance          float64
# Maximum Open Credit             float64
# Bankruptcies                    float64
# Tax Liens                       float64
# dtype: object

# %%
data['Loan ID'].duplicated().sum()
# Out:
# 18514

# %%
data1['Loan ID'].duplicated().sum()
# Out:
# 352

# %%
missing_value = pd.DataFrame(data.isnull().sum())

# %%
missing_value = missing_value.rename(columns ={'index':'Variables', 0:'Missing percentage'})
missing_value['Missing percentage'] = (missing_value['Missing percentage']/len(data))*100

# %%
missing_value
# Out:
#                               Missing percentage
# Loan ID                                 0.511372
# Customer ID                             0.511372
# Loan Status                             0.511372
# Current Loan Amount                     0.511372
# Term                                    0.511372
# Credit Score                           19.567423
# Annual Income                          19.567423
# Years in current job                    4.711781
# Home Ownership                          0.511372
# Purpose                                 0.511372
# Monthly Debt                            0.511372
# Years of Credit History                 0.511372
# Months since last delinquent           53.380624
# Number of Open Accounts                 0.511372
# Number of Credit Problems               0.511372
# Current Credit Balance                  0.511372
# Maximum Open Credit                     0.513361
# Bankruptcies                            0.714328
# ...

# %%
list(missing_value[missing_value['Missing percentage']>50].index)
# Out:
# ['Months since last delinquent']

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data.corr(), annot=True, linewidth = 0.5, cmap='coolwarm')

# %%
data['Loan Status'].value_counts()
# Out:
# Fully Paid     77361
# Charged Off    22639
# Name: Loan Status, dtype: int64

# %%
data['Loan Status'].fillna(data['Loan Status'].mode()[0], inplace=True)
data['Months since last delinquent'].fillna(data['Months since last delinquent'].mode()[0], inplace=True)
data['Term'].fillna(data['Term'].mode()[0], inplace=True)
data['Current Loan Amount'].fillna(data['Current Loan Amount'].mode()[0], inplace=True)
data['Credit Score'].fillna(data['Credit Score'].mode()[0], inplace=True)
data['Annual Income'].fillna(data['Annual Income'].mode()[0], inplace=True)
data['Years in current job'].fillna(data['Years in current job'].mode()[0], inplace =True)
data['Home Ownership'].fillna(data['Home Ownership'].mode()[0], inplace =True)
data['Purpose'].fillna(data['Purpose'].mode()[0], inplace =True)
data['Monthly Debt'].fillna(data['Monthly Debt'].mean(), inplace =True)
data['Years of Credit History'].fillna(data['Years of Credit History'].mean(), inplace =True)
data['Number of Open Accounts'].fillna(data['Number of Open Accounts'].mode()[0], inplace =True)
data['Number of Credit Problems'].fillna(data['Number of Credit Problems'].mode(), inplace =True)
data['Number of Open Accounts'].fillna(data['Number of Open Accounts'].mode()[0], inplace =True)
data['Maximum Open Credit'].fillna(data['Maximum Open Credit'].mean(), inplace =True)
data['Bankruptcies'].fillna(data['Bankruptcies'].mean(), inplace =True)
data['Tax Liens'].fillna(data['Tax Liens'].mode(), inplace =True)

# %%
data1['Months since last delinquent'].fillna(data1['Months since last delinquent'].mode()[0], inplace=True)
data1['Term'].fillna(data1['Term'].mode()[0], inplace=True)
data1['Current Loan Amount'].fillna(data1['Current Loan Amount'].mode()[0], inplace=True)
data1['Credit Score'].fillna(data1['Credit Score'].mode()[0], inplace=True)
data1['Annual Income'].fillna(data1['Annual Income'].mode()[0], inplace=True)
data1['Years in current job'].fillna(data1['Years in current job'].mode()[0], inplace =True)
data1['Home Ownership'].fillna(data1['Home Ownership'].mode()[0], inplace =True)
data1['Purpose'].fillna(data1['Purpose'].mode()[0], inplace =True)
data1['Monthly Debt'].fillna(data1['Monthly Debt'].mean(), inplace =True)
data1['Years of Credit History'].fillna(data1['Years of Credit History'].mean(), inplace =True)
data1['Number of Open Accounts'].fillna(data1['Number of Open Accounts'].mode()[0], inplace =True)
data1['Number of Credit Problems'].fillna(data1['Number of Credit Problems'].mode(), inplace =True)
data1['Number of Open Accounts'].fillna(data1['Number of Open Accounts'].mode()[0], inplace =True)
data1['Maximum Open Credit'].fillna(data1['Maximum Open Credit'].mean(), inplace =True)
data1['Bankruptcies'].fillna(data1['Bankruptcies'].mean(), inplace =True)
data1['Tax Liens'].fillna(data1['Tax Liens'].mode(), inplace =True)

# %%
data.dtypes
# Out:
# Loan ID                          object
# Customer ID                      object
# Loan Status                      object
# Current Loan Amount             float64
# Term                             object
# Credit Score                    float64
# Annual Income                   float64
# Years in current job             object
# Home Ownership                   object
# Purpose                          object
# Monthly Debt                    float64
# Years of Credit History         float64
# Months since last delinquent    float64
# Number of Open Accounts         float64
# Number of Credit Problems       float64
# Current Credit Balance          float64
# Maximum Open Credit             float64
# Bankruptcies                    float64
# Tax Liens                       float64
# dtype: object

# %%
 data1.dtypes
# Out:
# Loan ID                          object
# Customer ID                      object
# Current Loan Amount             float64
# Term                             object
# Credit Score                    float64
# Annual Income                   float64
# Years in current job             object
# Home Ownership                   object
# Purpose                          object
# Monthly Debt                    float64
# Years of Credit History         float64
# Months since last delinquent    float64
# Number of Open Accounts         float64
# Number of Credit Problems       float64
# Current Credit Balance          float64
# Maximum Open Credit             float64
# Bankruptcies                    float64
# Tax Liens                       float64
# dtype: object

# %%
numerical_vars =['Credit Score', 'Annual Income', 'Years in current job',
       'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
        'Number of Open Accounts',
       'Number of Credit Problems', 'Current Credit Balance',
       'Maximum Open Credit', 'Bankruptcies', 'Tax Liens']

# %%
data[numerical_vars].hist(edgecolor='black', bins=14, figsize=(70,60), layout=(20,20));

# %%
data['Home Ownership'] = data['Home Ownership'].astype(str).str.lower()
data['Purpose'] = data['Purpose'].astype(str).str.lower()

# %%
data1['Home Ownership'] = data1['Home Ownership'].astype(str).str.lower()
data1['Purpose'] = data1['Purpose'].astype(str).str.lower()

# %%
data['Purpose'].unique()
# Out:
# array(['home improvements', 'debt consolidation', 'buy house', 'other',
#        'business loan', 'buy a car', 'major_purchase', 'take a trip',
#        'small_business', 'medical bills', 'wedding', 'vacation',
#        'educational expenses', 'moving', 'renewable_energy'], dtype=object)

# %% [markdown]
# ## MAPPING DICT

# %%
personal = ['home improvements',  'buy house', 'other','buy a car', 'major_purchase', 'take a trip', 'wedding', 'vacation','moving' ]
business = ['debt consolidation', 'business loan', 'small_business', 'medical bills', 'educational expenses', 'renewable_energy']

def pue(x):
    if x in personal:
        return 'personal'
    else:
        return 'business'
    
data['Purpose']= data['Purpose'].apply(lambda x: pue(x))

# %%
personal = ['home improvements',  'buy house', 'other','buy a car', 'major_purchase', 'take a trip', 'wedding', 'vacation','moving' ]
business = ['debt consolidation', 'business loan', 'small_business', 'medical bills', 'educational expenses', 'renewable_energy']

def pue(x):
    if x in personal:
        return 'personal'
    else:
        return 'business'
    
data1['Purpose']= data1['Purpose'].apply(lambda x: pue(x))

# %%
data['Purpose'].unique()
# Out:
# array(['personal', 'business'], dtype=object)

# %%
data['Home Ownership'].unique()
# Out:
# array(['home mortgage', 'own home', 'rent', 'havemortgage'], dtype=object)

# %%
mapping_dict_1 ={
    'Home Ownership':{
    'home mortgage':1, 
    'own home':2,
    'rent':3, 
    'havemortgage':1,
    }
}
data.replace(mapping_dict_1, inplace =True)

# %%
mapping_dict_1 ={
    'Home Ownership':{
    'home mortgage':1, 
    'own home':2,
    'rent':3, 
    'havemortgage':1,
    }
}
data1.replace(mapping_dict_1, inplace =True)

# %%
data['Years in current job'].unique()
# Out:
# array(['8 years', '10+ years', '3 years', '5 years', '< 1 year',
#        '2 years', '4 years', '9 years', '7 years', '1 year', '6 years'],
#       dtype=object)

# %%
mapping_dict_2={
    'Years in current job':{
        '8 years': 8, 
        '10+ years': 10, 
        '3 years':3, 
        '5 years':5, 
        '< 1 year':1,
       '2 years':2,
        '4 years':4, 
        '9 years':9, 
        '7 years':7, 
        '1 year':1, 
        '6 years':6,
        
    }
}
data.replace(mapping_dict_2, inplace=True)

# %%
mapping_dict_2={
    'Years in current job':{
        '8 years': 8, 
        '10+ years': 10, 
        '3 years':3, 
        '5 years':5, 
        '< 1 year':1,
       '2 years':2,
        '4 years':4, 
        '9 years':9, 
        '7 years':7, 
        '1 year':1, 
        '6 years':6,
        
    }
}
data1.replace(mapping_dict_2, inplace=True)

# %%
data['Term'].unique()
# Out:
# array(['Short Term', 'Long Term'], dtype=object)

# %%
mapping_dict_3={
    'Term':{
       'Short Term':0, 
        'Long Term':1,
        
    }
}
data.replace(mapping_dict_3, inplace=True)

# %%
mapping_dict_3={
    'Term':{
       'Short Term':0, 
        'Long Term':1,
        
    }
}
data1.replace(mapping_dict_3, inplace=True)

# %%
data['Loan Status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off'], dtype=object)

# %%
mapping_dict_4={
    'Loan Status':{
       'Fully Paid':0, 
        'Charged Off':1,
        
    }
}
data.replace(mapping_dict_4, inplace=True)

# %%
mapping_dict_4={
    'Loan Status':{
       'Fully Paid':0, 
        'Charged Off':1,
        
    }
}
data1.replace(mapping_dict_4, inplace=True)

# %%
mapping_dict_5={
    'Purpose':{
       'personal':0, 
        'business':1,
        
    }
}
data.replace(mapping_dict_5, inplace=True)

# %%
mapping_dict_5={
    'Purpose':{
       'personal':0, 
        'business':1,
        
    }
}
data1.replace(mapping_dict_5, inplace=True)

# %%
data.dtypes
# Out:
# Loan ID                          object
# Customer ID                      object
# Loan Status                       int64
# Current Loan Amount             float64
# Term                              int64
# Credit Score                    float64
# Annual Income                   float64
# Years in current job              int64
# Home Ownership                    int64
# Purpose                           int64
# Monthly Debt                    float64
# Years of Credit History         float64
# Months since last delinquent    float64
# Number of Open Accounts         float64
# Number of Credit Problems       float64
# Current Credit Balance          float64
# Maximum Open Credit             float64
# Bankruptcies                    float64
# Tax Liens                       float64
# dtype: object

# %%
data['Customer ID'].duplicated().sum()
# Out:
# 18514

# %%
data1['Loan ID'].duplicated().sum()
# Out:
# 352

# %%
data.drop_duplicates("Customer ID", keep='last', inplace=True)

# %%
data1.drop_duplicates("Customer ID", keep='last', inplace=True)

# %%
data['Customer ID'].duplicated().sum()
# Out:
# 0

# %%
data1.drop_duplicates("Customer ID", keep='last', inplace=True)

# %%
data1['Customer ID'].duplicated().sum()
# Out:
# 0

# %%
data.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
# 5  89d8cb0c-e5c2-4f54-b056-48a645c543dd  4ffe99d3-7f2a-44db-afc1-40943f1f9750
# 6  273581de-85d8-4332-81a5-19b04ce68666  90a75dde-34d5-419c-90dc-1e58b04b3e35
# 7  db0dc6e1-77ee-4826-acca-772f9039e1c7  018973c9-e316-4956-b363-67e134fb0931
#
#    Loan Status  Current Loan Amount  Term  Credit Score  Annual Income  \
# 1            0             262328.0     0         747.0      1162572.0
# 2            0           99999999.0     0         741.0      2231892.0
# 5            1             206602.0     0        7290.0       896857.0
# 6            0             217646.0     0         730.0      1184194.0
# 7            1             648714.0     1         747.0      1162572.0
#
#    Years in current job  Home Ownership  Purpose  Monthly Debt  \
# ...

# %%
data.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
data1.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Current Loan Amount', 'Term', 'Credit Score',
#        'Annual Income', 'Years in current job', 'Home Ownership', 'Purpose',
#        'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
data.to_csv('data1.csv')

# %%
data1.to_csv('data2.csv')

# %%
dataset = pd.read_csv('data1.csv', delimiter=",")

# %%
dataset1 = pd.read_csv('data2.csv')

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Loan ID', 'Customer ID', 'Loan Status',
#        'Current Loan Amount', 'Term', 'Credit Score', 'Annual Income',
#        'Years in current job', 'Home Ownership', 'Purpose', 'Monthly Debt',
#        'Years of Credit History', 'Months since last delinquent',
#        'Number of Open Accounts', 'Number of Credit Problems',
#        'Current Credit Balance', 'Maximum Open Credit', 'Bankruptcies',
#        'Tax Liens'],
#       dtype='object')

# %%
dataset1.columns
# Out:
# Index(['Unnamed: 0', 'Loan ID', 'Customer ID', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
dataset.head(5)
# Out:
#    Unnamed: 0                               Loan ID  \
# 0           1  4771cc26-131a-45db-b5aa-537ea4ba5342
# 1           2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 2           5  89d8cb0c-e5c2-4f54-b056-48a645c543dd
# 3           6  273581de-85d8-4332-81a5-19b04ce68666
# 4           7  db0dc6e1-77ee-4826-acca-772f9039e1c7
#
#                             Customer ID  Loan Status  Current Loan Amount  \
# 0  2de017a3-2e01-49cb-a581-08169e83be29            0             262328.0
# 1  5efb2b2b-bf11-4dfd-a572-3761a2694725            0           99999999.0
# 2  4ffe99d3-7f2a-44db-afc1-40943f1f9750            1             206602.0
# 3  90a75dde-34d5-419c-90dc-1e58b04b3e35            0             217646.0
# 4  018973c9-e316-4956-b363-67e134fb0931            1             648714.0
#
#    Term  Credit Score  Annual Income  Years in current job  Home Ownership  \
# 0     0         747.0      1162572.0                    10               1
# ...

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0                      0
# Loan ID                         1
# Customer ID                     1
# Loan Status                     0
# Current Loan Amount             0
# Term                            0
# Credit Score                    0
# Annual Income                   0
# Years in current job            0
# Home Ownership                  0
# Purpose                         0
# Monthly Debt                    0
# Years of Credit History         0
# Months since last delinquent    0
# Number of Open Accounts         0
# Number of Credit Problems       1
# Current Credit Balance          1
# Maximum Open Credit             0
# Bankruptcies                    0
# Tax Liens                       9
# dtype: int64

# %%
dataset1.isnull().sum()
# Out:
# Unnamed: 0                      0
# Loan ID                         1
# Customer ID                     1
# Current Loan Amount             0
# Term                            0
# Credit Score                    0
# Annual Income                   0
# Years in current job            0
# Home Ownership                  0
# Purpose                         0
# Monthly Debt                    0
# Years of Credit History         0
# Months since last delinquent    0
# Number of Open Accounts         0
# Number of Credit Problems       1
# Current Credit Balance          1
# Maximum Open Credit             0
# Bankruptcies                    0
# Tax Liens                       2
# dtype: int64

# %%
plt.subplot(121)
sns.distplot(dataset['Current Loan Amount']);

plt.subplot(122)
dataset['Current Loan Amount'].plot.box(figsize=(16,5))

plt.show()

# %%
plt.subplot(121)
sns.distplot(dataset1['Current Loan Amount']);

plt.subplot(122)
dataset1['Current Loan Amount'].plot.box(figsize=(16,5))

plt.show()

# %%
dataset.boxplot(column='Current Loan Amount', by = 'Loan Status')
plt.suptitle("")
# Out:
# Text(0.5, 0.98, '')

# %%
plt.subplot(121)
dataset=dataset.dropna()
sns.distplot(dataset['Annual Income']);

plt.subplot(122)
dataset['Annual Income'].plot.box(figsize=(16,5))

plt.show()

# %%
plt.subplot(121)
dataset1=dataset1.dropna()
sns.distplot(dataset1['Annual Income']);

plt.subplot(122)
dataset1['Annual Income'].plot.box(figsize=(16,5))

plt.show()

# %%
plt.subplot(121)
dataset=dataset.dropna()
sns.distplot(dataset['Current Credit Balance']);

plt.subplot(122)
dataset['Current Credit Balance'].plot.box(figsize=(16,5))

plt.show()

# %%
plt.subplot(121)
dataset1=dataset1.dropna()
sns.distplot(dataset1['Current Credit Balance']);

plt.subplot(122)
dataset1['Current Credit Balance'].plot.box(figsize=(16,5))

plt.show()

# %%
plt.subplot(121)
dataset=dataset.dropna()
sns.distplot(dataset['Number of Credit Problems']);

plt.subplot(122)
dataset['Number of Credit Problems'].plot.box(figsize=(16,5))

plt.show()

# %%
plt.subplot(121)
dataset1=dataset1.dropna()
sns.distplot(dataset1['Number of Credit Problems']);

plt.subplot(122)
dataset1['Number of Credit Problems'].plot.box(figsize=(16,5))

plt.show()

# %%
plt.subplot(121)
dataset=dataset.dropna()
sns.distplot(dataset['Tax Liens']);

plt.subplot(122)
dataset['Tax Liens'].plot.box(figsize=(16,5))

plt.show()

# %%
plt.subplot(121)
dataset1=dataset1.dropna()
sns.distplot(dataset1['Tax Liens']);

plt.subplot(122)
dataset1['Tax Liens'].plot.box(figsize=(16,5))

plt.show()

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Loan ID', 'Customer ID', 'Loan Status',
#        'Current Loan Amount', 'Term', 'Credit Score', 'Annual Income',
#        'Years in current job', 'Home Ownership', 'Purpose', 'Monthly Debt',
#        'Years of Credit History', 'Months since last delinquent',
#        'Number of Open Accounts', 'Number of Credit Problems',
#        'Current Credit Balance', 'Maximum Open Credit', 'Bankruptcies',
#        'Tax Liens'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (81991, 20)

# %%
dataset1.shape
# Out:
# (9999, 19)

# %%
(len (dataset), len (dataset1))
# Out:
# (81991, 9999)

# %%
dataset1.columns
# Out:
# Index(['Unnamed: 0', 'Loan ID', 'Customer ID', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0                      0
# Loan ID                         0
# Customer ID                     0
# Loan Status                     0
# Current Loan Amount             0
# Term                            0
# Credit Score                    0
# Annual Income                   0
# Years in current job            0
# Home Ownership                  0
# Purpose                         0
# Monthly Debt                    0
# Years of Credit History         0
# Months since last delinquent    0
# Number of Open Accounts         0
# Number of Credit Problems       0
# Current Credit Balance          0
# Maximum Open Credit             0
# Bankruptcies                    0
# Tax Liens                       0
# dtype: int64

# %%
dataset1.isnull().sum()
# Out:
# Unnamed: 0                      0
# Loan ID                         0
# Customer ID                     0
# Current Loan Amount             0
# Term                            0
# Credit Score                    0
# Annual Income                   0
# Years in current job            0
# Home Ownership                  0
# Purpose                         0
# Monthly Debt                    0
# Years of Credit History         0
# Months since last delinquent    0
# Number of Open Accounts         0
# Number of Credit Problems       0
# Current Credit Balance          0
# Maximum Open Credit             0
# Bankruptcies                    0
# Tax Liens                       0
# dtype: int64

# %%
to_drop =['Loan ID', 'Customer ID']
dataset.drop(to_drop, inplace=True, axis=1)

# %% [markdown]
# ## Built Modelling

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
X = dataset.loc[:, dataset.columns != 'Loan Status']
y = dataset.loc[:, 'Loan Status']
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=123)
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
predictions = [round(value) for value in y_pred]
# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 78.35%

# %%
 y_pred
# Out:
# array([0, 1, 0, ..., 1, 0, 0], dtype=int64)

# %%
X_test.columns
# Out:
# Index(['Unnamed: 0', 'Current Loan Amount', 'Term', 'Credit Score',
#        'Annual Income', 'Years in current job', 'Home Ownership', 'Purpose',
#        'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
dataset1.shape
# Out:
# (9999, 19)

# %%
data_test = dataset1[X.columns]

# %%
data_test.shape
# Out:
# (9999, 17)

# %%
data_test.dtypes
# Out:
# Unnamed: 0                        int64
# Current Loan Amount             float64
# Term                              int64
# Credit Score                    float64
# Annual Income                   float64
# Years in current job              int64
# Home Ownership                    int64
# Purpose                           int64
# Monthly Debt                    float64
# Years of Credit History         float64
# Months since last delinquent    float64
# Number of Open Accounts         float64
# Number of Credit Problems       float64
# Current Credit Balance          float64
# Maximum Open Credit             float64
# Bankruptcies                    float64
# Tax Liens                       float64
# dtype: object

# %%
dataset1['predictions'] = model.predict(data_test)

# %%
dataset1
# Out:
#       Unnamed: 0                               Loan ID  \
# 0              0  f738779f-c726-40dc-92cf-689d73af533d
# 1              1  6dcc0947-164d-476c-a1de-3ae7283dde0a
# 2              2  f7744d01-894b-49c3-8777-fc6431a2cff1
# 3              3  83721ffb-b99a-4a0f-aea5-ef472a138b41
# 4              4  08f3789f-5714-4b10-929d-e1527ab5e5a3
# 5              5  a4957169-d809-44cc-847b-975400bc8d11
# 6              6  43467302-94fe-494b-b52f-3fd891fea71c
# 7              7  930c7cb3-6086-434a-9547-3ed41c181552
# 8              8  0b2f1b66-741e-4e37-a929-99926cdc9e9a
# 9              9  d08f3a5e-93df-40e7-bdd8-cba59180bddf
# 10            10  3102b699-a2d2-4df4-9c33-005dc41e3525
# 11            11  663ad9a3-4691-4f8c-90c6-75a5f4f0b34f
# 12            12  1e277d73-10b5-475f-8538-2a5a09d62c8d
# 13            13  79d992b7-0aa7-4059-a10b-3d416809d77e
# 14            14  c3c63911-be01-410b-a20a-85cb9bb83712
# 15            15  a913063f-af67-4a8d-b663-e83b9085180d
# ...

# %%
dataset1['predictions'].value_counts()
# Out:
# 0    7881
# 1    2118
# Name: predictions, dtype: int64

# %%
ax1 = plt.subplot(121)
dataset['Current Loan Amount'].hist(bins=20, figsize=(12,4))
ax1.set_title("train")

ax2 = plt.subplot(122)
dataset1['Current Loan Amount'].hist(bins=20)
ax2.set_title("test")
# Out:
# Text(0.5, 1.0, 'test')

# %%
# Removing skewness in LoanAmount variable by log transformation
dataset['LoanAmount_log'] = np.log(dataset['Current Loan Amount'])
dataset1['LoanAmount_log'] = np.log(dataset1['Current Loan Amount'])

# %%
ax1 = plt.subplot(121)
dataset['LoanAmount_log'].hist(bins=20, figsize=(12,4))
ax1.set_title("Train")

ax2 = plt.subplot(122)
dataset1['LoanAmount_log'].hist(bins=20)
ax2.set_title("Test")
# Out:
# Text(0.5, 1.0, 'Test')

# %% [markdown]
# ### EVALUATION MODELLING

# %%
from sklearn.metrics import confusion_matrix
 
cm = confusion_matrix(y_test, predictions )
print(cm)

# f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(cm, annot=True, fmt="d")
plt.title('Confusion matrix of the classifier')
plt.xlabel('Predicted')
plt.ylabel('True')
# Out:
# [[11644   169]
#  [ 3381  1205]]
# Text(33.0, 0.5, 'True')

# %%
# import classification_report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.99      0.87     11813
#            1       0.88      0.26      0.40      4586
#
#     accuracy                           0.78     16399
#    macro avg       0.83      0.62      0.64     16399
# weighted avg       0.80      0.78      0.74     16399
